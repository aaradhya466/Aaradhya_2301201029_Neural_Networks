# %%
from keras.models import Sequential
from keras.layers import Dense
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# Load Data
data = load_iris()
X = data.data
y = to_categorical(data.target)

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Model
model = Sequential()
model.add(Dense(10, input_dim=4, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(3, activation='softmax'))

# Compile
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train
history = model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test))

# Plot
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Model Accuracy")
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 0.3417 - loss: 1.3221 - val_accuracy: 0.3000 - val_loss: 1.2618
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.3417 - loss: 1.2475 - val_accuracy: 0.3000 - val_loss: 1.2006
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3417 - loss: 1.1896 - val_accuracy: 0.3000 - val_loss: 1.1437
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.3417 - loss: 1.1255 - val_accuracy: 0.3000 - val_loss: 1.0934
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3417 - loss: 1.0703 - val_accuracy: 0.3333 - val_loss: 1.0474
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3500 - loss: 1.0209 - val_accuracy: 0.4333 - val_loss: 1.0001
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4000 - loss: 0.9750 - val_accuracy: 0.5000 - val_loss: 0.9581
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.4500 - loss: 0.9321 - val_accuracy: 0.5333 - val_loss: 0.9224
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5583 - loss: 0.8977 - val_accuracy: 0.6333 - val_loss: 0.8904
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6167 - loss: 0.8701 - val_accuracy: 0.6333 - val_loss: 0.8621
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6083 - loss: 0.8414 - val_accuracy: 0.6000 - val_loss: 0.8371
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6667 - loss: 0.8183 - val_accuracy: 0.6667 - val_loss: 0.8117
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6583 - loss: 0.7994 - val_accuracy: 0.6667 - val_loss: 0.7880
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6583 - loss: 0.7782 - val_accuracy: 0.7000 - val_loss: 0.7624
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6583 - loss: 0.7578 - val_accuracy: 0.7000 - val_loss: 0.7389
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6583 - loss: 0.7401 - val_accuracy: 0.7000 - val_loss: 0.7162
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6583 - loss: 0.7218 - val_accuracy: 0.7000 - val_loss: 0.6967
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6667 - loss: 0.7061 - val_accuracy: 0.7000 - val_loss: 0.6787
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6583 - loss: 0.6918 - val_accuracy: 0.7000 - val_loss: 0.6634
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6667 - loss: 0.6782 - val_accuracy: 0.7000 - val_loss: 0.6502
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6667 - loss: 0.6670 - val_accuracy: 0.7000 - val_loss: 0.6376
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6667 - loss: 0.6562 - val_accuracy: 0.7000 - val_loss: 0.6258
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6667 - loss: 0.6456 - val_accuracy: 0.7000 - val_loss: 0.6150
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6667 - loss: 0.6358 - val_accuracy: 0.7000 - val_loss: 0.6046
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6583 - loss: 0.6262 - val_accuracy: 0.7000 - val_loss: 0.5937
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6667 - loss: 0.6171 - val_accuracy: 0.7000 - val_loss: 0.5834
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6583 - loss: 0.6087 - val_accuracy: 0.7000 - val_loss: 0.5741
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6583 - loss: 0.5999 - val_accuracy: 0.7000 - val_loss: 0.5635
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6667 - loss: 0.5917 - val_accuracy: 0.7000 - val_loss: 0.5536
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6667 - loss: 0.5845 - val_accuracy: 0.7000 - val_loss: 0.5430
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6667 - loss: 0.5763 - val_accuracy: 0.7000 - val_loss: 0.5343
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6667 - loss: 0.5687 - val_accuracy: 0.7000 - val_loss: 0.5256
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6667 - loss: 0.5623 - val_accuracy: 0.7000 - val_loss: 0.5171
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6750 - loss: 0.5553 - val_accuracy: 0.7000 - val_loss: 0.5093
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6917 - loss: 0.5490 - val_accuracy: 0.7000 - val_loss: 0.5014
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6917 - loss: 0.5423 - val_accuracy: 0.7000 - val_loss: 0.4946
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6833 - loss: 0.5367 - val_accuracy: 0.7000 - val_loss: 0.4885
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6917 - loss: 0.5308 - val_accuracy: 0.7000 - val_loss: 0.4811
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7000 - loss: 0.5252 - val_accuracy: 0.7333 - val_loss: 0.4745
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6917 - loss: 0.5204 - val_accuracy: 0.7000 - val_loss: 0.4689
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6917 - loss: 0.5144 - val_accuracy: 0.7667 - val_loss: 0.4629
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7083 - loss: 0.5098 - val_accuracy: 0.7667 - val_loss: 0.4563
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7250 - loss: 0.5047 - val_accuracy: 0.7667 - val_loss: 0.4505
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7250 - loss: 0.4996 - val_accuracy: 0.7667 - val_loss: 0.4457
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7250 - loss: 0.4950 - val_accuracy: 0.7667 - val_loss: 0.4408
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7333 - loss: 0.4904 - val_accuracy: 0.7667 - val_loss: 0.4358
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7417 - loss: 0.4860 - val_accuracy: 0.8000 - val_loss: 0.4305
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7583 - loss: 0.4815 - val_accuracy: 0.8333 - val_loss: 0.4259
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7833 - loss: 0.4771 - val_accuracy: 0.8333 - val_loss: 0.4214
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7750 - loss: 0.4726 - val_accuracy: 0.8000 - val_loss: 0.4173
